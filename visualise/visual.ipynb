# %%
# Test matplotlib
import matplotlib.pyplot as plt

squares = [1, 4, 9, 16, 25]
plt.plot(squares, linewidth=5)

# Set chart title and label axis
plt.title("Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both', labelsize=14)

print(plt.show())
# Out:
# None

# %%
# Test matplotlib
import matplotlib.pyplot as plt

input_values = [1,2,3,4,5]
squares = [1, 4, 9, 16, 25]
plt.plot(input_values,squares, linewidth=5)

# Set chart title and label axis
plt.title("Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both', labelsize=14)

print(plt.show())
# Out:
# None

# %%
import matplotlib.pyplot as plt

plt.scatter(2,4,s=200)

#Set chart title and label axis
plt.title("Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=14)
plt.ylabel("square", fontsize=14)

#Set size of tick labels
plt.tick_params(axis='both', which='major', labelsize=14)

plt.show()

# %%
# Test matplotlib
import matplotlib.pyplot as plt

input_val = [1,2,3,4,5]
squares = [1, 4, 9, 16, 25]
plt.scatter(input_val,squares)

# Set chart title and label axis
plt.title("Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both', which='major', labelsize=14)

print(plt.show())
# Out:
# None

# %%
# Test matplotlib
import matplotlib.pyplot as plt

xvalues = list(range(1,251))
yvalues = [x**2 for x in xvalues]

plt.scatter(xvalues,yvalues,c = 'red', edgecolor='none',s=50)

# Set chart title and label axis
plt.title("Scatter Plot Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both',which='major', labelsize=14)

plt.show()

# %%
# Test matplotlib
import matplotlib.pyplot as plt

xvalues = list(range(1,251))
yvalues = [x**2 for x in xvalues]

plt.scatter(xvalues,yvalues,c=yvalues,cmap=plt.cm.Greens, edgecolor='none',s=50)

# Set chart title and label axis
plt.title("Scatter Plot Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both',which='major', labelsize=14)

plt.show()

# %%
# Test matplotlib
import matplotlib.pyplot as plt

xvalues = list(range(1,251))
yvalues = [x**2 for x in xvalues]

plt.scatter(xvalues,yvalues,c=yvalues,cmap=plt.cm.Greens, edgecolor='none',s=50)

# Set chart title and label axis
plt.title("Scatter Plot Square Numbers", fontsize=24)
plt.xlabel("value", fontsize=18)
plt.ylabel("Square of x", fontsize=18)

# Set size of tick labels
plt.tick_params(axis='both',which='major', labelsize=14)

#plt.show()
plt.savefig('images/squares_plot.png',bbox_inches='tight')

# %%
# Cubes

import matplotlib.pyplot as plt

xvalues = list(range(1,100))
yvalues = [x**3 for x in xvalues]
#print(yvalues)

plt.scatter(xvalues,yvalues,s=30)

#Name the plot
plt.title('Number vs Cube Plot', fontsize=25)
plt.xlabel('x', fontsize=14)
plt.ylabel('Cube(x)',fontsize=14)

#Set size of tick labels
plt.tick_params(axis='both', which='major', labelsize=14)

#Save the Image
#plt.show()
plt.savefig('images/cube.png',bbox_inches='tight')

# %%
# Cube with color map
# Cubes

import matplotlib.pyplot as plt

xvalues = list(range(1,200))
yvalues = [x**3 for x in xvalues]
#print(yvalues)

plt.scatter(xvalues,yvalues,c=yvalues,cmap=plt.cm.Blues,edgecolor='none',s=50)

#Name the plot
plt.title('Number vs Cube Plot', fontsize=25)
plt.xlabel('x', fontsize=14)
plt.ylabel('Cube(x)',fontsize=14)

#Set size of tick labels
plt.tick_params(axis='both', which='major', labelsize=14)

#Save the Image
#plt.show()
plt.savefig('images/cube_cmap.png',bbox_inches='tight')

# %%
#Random Walk - 
from random import choice

class RandomWalk():
    """A class that generates random walks"""
    
    def __init__(self, num_points=50000):
        """Initialise attributes of a walk"""
        self.num_points = num_points
        
        #All Walks start at (0,0)
        self.xval = [0]
        self.yval = [0]
        
    def fill_walk(self):
        """Calculate all points in a walk"""
        # print("In fill walk")
        while(len(self.xval) < self.num_points):
            #Decide which direction to go and how far:
            #print('in while loop')
            x_dir = choice([-1,1])
            x_dist = choice(list(range(0,5)))
            x_step = x_dir * x_dist
            #print('xval:',x_step)
        
            y_dir = choice([-1,1])
            y_dist = choice(list(range(0,5)))
            y_step = y_dir * y_dist
            #print('yval',y_step)
            #print()
            #Reject moves that go nowhere
            if x_step==0 and y_step==0:
                continue
            
            #Calculate the next x and y values:
            next_x = self.xval[-1] + x_step
            next_y = self.yval[-1] + y_step
            
            self.xval.append(next_x)
            self.yval.append(next_y)

# %%
# Plot the Random Walk
import matplotlib.pyplot as plt

i = 0
while True:
    rw = RandomWalk()
    rw.fill_walk()
    fileName = 'images/RandomWalk' + str(i) + '.png'
    i+=1
    plt.figure()
    points = list(range(rw.num_points))
    plt.scatter(rw.xval,rw.yval, c=points, cmap=plt.cm.Blues, s=15)
    
    #Emphasize the first point and the last point
    plt.scatter(0,0, c='red',edgecolor='none',s=100)
    plt.scatter(rw.xval[-1],rw.yval[-1],c='green', edgecolor='none', s=100)
    
    # Remove the axis
    plt.axes().get_xaxis().set_visible(False)
    plt.axes().get_yaxis().set_visible(False)
    
    plt.title(fileName, fontsize=24)
    plt.savefig(fileName,bbox_inches='tight')
    
    keep_running = input('Do you want to try again (y/n): ')
    if keep_running == 'n':
        break
# Out:
# In fill walk
# /home/prashanth/.virtualenvs/cv/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Do you want to try again (y/n): y
# In fill walk
# Do you want to try again (y/n): y
# In fill walk
# Do you want to try again (y/n): n

# %%
# Plot the Random Walk 50000 points
import matplotlib.pyplot as plt

i = 0
while True:
    rw = RandomWalk()
    rw.fill_walk()
    fileName = 'images/RandomWalk' + str(i) + '.png'
    i+=1
    plt.figure(dpi=128, figsize=(10,6))
    points = list(range(rw.num_points))
    plt.scatter(rw.xval,rw.yval, c=points, cmap=plt.cm.Blues, s=15)
    
    #Emphasize the first point and the last point
    plt.scatter(0,0, c='red',edgecolor='none',s=100)
    plt.scatter(rw.xval[-1],rw.yval[-1],c='green', edgecolor='none', s=100)
    
    # Remove the axis
    plt.axes().get_xaxis().set_visible(False)
    plt.axes().get_yaxis().set_visible(False)
    
    plt.title(fileName, fontsize=24)
    plt.savefig(fileName,bbox_inches='tight')
    
    keep_running = input('Do you want to try again (y/n): ')
    if keep_running == 'n':
        break
# Out:
# /home/prashanth/.virtualenvs/cv/lib/python3.5/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# Do you want to try again (y/n): n
